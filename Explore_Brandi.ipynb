# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format
import warnings
warnings.filterwarnings("ignore")

from scipy import stats 

import seaborn as sns

import matplotlib.pyplot as plt

df = pd.read_csv('train.csv')

# %%
with pd.option_context('display.max_columns', None):
    display(df.head())
# Out:
#    Unnamed: 0 customer_id churn  churn_enc  tenure  tenure_years  tenure_nml  \
# 0        5691  5762-TJXGK    No          0      52         4.330       0.560
# 1        6232  6242-FEGFD    No          0      66         5.500       1.074
# 2        5807  7359-SSBJK   Yes          1      64         5.330       0.967
# 3        2746  7024-OHCCK   Yes          1       2         0.170      -1.221
# 4        3143  9054-FOWNV    No          0      22         1.830      -0.217
#
#    monthly_charges  monthly_charges_nml  total_charges  total_charges_nml  \
# 0           58.750               -0.271       3038.550              0.486
# 1           96.600                0.971       6424.250              1.454
# 2           70.200               -0.037       4481.000              0.820
# 3           93.850                0.787        170.850             -1.012
# 4           88.750                0.601       1885.150              0.191
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 0], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services > 0], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 1], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 2], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 3], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 4], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 5], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 6], hue='churn')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='tenure', y='monthly_charges', data=df[df.internet_services == 7], hue='churn')

# %%
# Since there are some variations in churn raate among services, I'll look at each individually. I needed to add those columns back into the train df

# %%
g = sns.FacetGrid(df, col="online_security_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="online_backup_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="device_protection_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="tech_support_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="streaming_movies_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="streaming_tv_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="senior_citizen", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="gender_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="family_support", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="extra_lines", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="paperless_billing_enc", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="pay_auto", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
g = sns.FacetGrid(df, col="has_internet", hue='churn', margin_titles=True, height=10)
g.map(plt.scatter, "tenure", "monthly_charges")

# %%
# People who churn pay more per month than those who don't
df[df.churn == 'Yes'].monthly_charges.median(), df[df.churn == 'No'].monthly_charges.median()
# Out:
# (80.45, 64.75)

# %%
# Find rate of churn for people with phone service only, vs those with internet
# Number of people who churn out of those who have internet / All those with internet
churn_with_internet = df[df.has_internet == 1][df.churn == 'Yes'].shape[0]
all_with_internet = df[df.has_internet == 1].shape[0]

churn_with_internet / all_with_internet
# Out:
# 0.3376029277218664

# %%
churn_phone_only = df[df.has_internet == 0][df.churn == 'Yes'].shape[0]
all_phone_only = df[df.has_internet == 0].shape[0]

churn_phone_only / all_phone_only
# Out:
# 0.07278481012658228

# %%
# So ppl with internet churn way more than those with phone svc only

# %%
# Lets find rate of churn for the different types of internet
# 1 = DSL, 2 = Fiber Optic, 3 = None
num_dsl_churn = df[df.internet_service_type_id == 1][df.churn == 'Yes'].shape[0]
num_dsl = df[df.internet_service_type_id == 1].shape[0]

num_dsl_churn / num_dsl
# Out:
# 0.19047619047619047

# %%
num_fo_churn = df[df.internet_service_type_id == 2][df.churn == 'Yes'].shape[0]
num_fo = df[df.internet_service_type_id == 2].shape[0]

num_fo_churn / num_fo
# Out:
# 0.44532488114104596

# %%
churn_phone_only = df[df.has_internet == 0][df.churn == 'Yes'].shape[0]
all_phone_only = df[df.has_internet == 0].shape[0]

churn_phone_only / all_phone_only
# Out:
# 0.07278481012658228

# %%
# So fiber optic has the highest rate of churn

# %%
# Do customers get a discount for paying automatically?
df[df.has_internet == 0][df.extra_lines == 1][df.pay_auto == 0].monthly_charges.median()
# Out:
# 20.0

# %%
df[df.has_internet == 0][df.extra_lines == 1][df.pay_auto == 1].monthly_charges.median()
# Out:
# 19.85

# %%
df[df.pay_auto == 0].monthly_charges.median()
# Out:
# 70.1

# %%
df[df.pay_auto == 1].monthly_charges.median()
# Out:
# 74.55

# %%
# Nope

# %%
# Do they get a discount for being a senior citizen?
df[df.has_internet == 0][df.extra_lines == 1][df.senior_citizen == 0].monthly_charges.median()
# Out:
# 19.9

# %%
df[df.has_internet == 0][df.extra_lines == 1][df.senior_citizen == 1].monthly_charges.median()
# Out:
# 19.45

# %%
# Nope, senior citizens actually pay slightly more (0.05 more, but still)

# %%
# Run t-tests 
x1 = df[df.has_internet == 0].churn_enc
x2 = df[df.has_internet == 1].churn_enc

stats.ttest_ind(x1, x2)
# Out:
# Ttest_indResult(statistic=-9.54016418101425, pvalue=6.034052853716749e-21)

# %%
with pd.option_context('display.max_columns', None):
    display(df[df.has_internet == 1])
# Out:
#       Unnamed: 0 customer_id churn  churn_enc  tenure  tenure_years  \
# 0           5691  5762-TJXGK    No          0      52         4.330
# 1           6232  6242-FEGFD    No          0      66         5.500
# 2           5807  7359-SSBJK   Yes          1      64         5.330
# 3           2746  7024-OHCCK   Yes          1       2         0.170
# 4           3143  9054-FOWNV    No          0      22         1.830
# ...          ...         ...   ...        ...     ...           ...
# 1404        4056  3229-USWAR    No          0      34         2.830
# 1405        1026  8260-NGFNY   Yes          1       1         0.080
# 1406        2386  5334-JLAXU    No          0      60         5.000
# 1407        1776  2674-MIAHT    No          0       4         0.330
# 1408        1723  2452-SNHFZ    No          0      47         3.920
#
#       tenure_nml  monthly_charges  monthly_charges_nml  total_charges  \
# 0          0.560           58.750               -0.271       3038.550
# ...

# %%
# Lets find out the cost of services
# First look at those with only one line
phone_svc = df[df.contract_type_id == 3][df.has_internet == 0][df.extra_lines == 1].monthly_charges.median()
# Subtract the avg of multiple lines from one line to get the added cost of extra lines
phone_extra = (df[df.contract_type_id == 3][df.has_internet == 0][df.extra_lines == 2].monthly_charges.median() - phone_svc)
# Now lets look at prices for internet and its services
DSL = df[df.phone_service_enc == 0][df.contract_type_id == 1]
FO = df[df.phone_service_enc == 0][df.contract_type_id == 2]
DSL2 = df[df.contract_type_id == 1]
FO2 = df[df.contract_type_id == 2]
# Cost for DSL:
DSL_cost = DSL[df.internet_services == 1].monthly_charges.median()
# Cost for Fiber optic:
FO_cost = FO[df.internet_services == 1].monthly_charges.median()
# Online_security w/ DSL:
DSL_Onl_sec = (DSL[df.internet_services == 2][df.online_security_enc == 1].monthly_charges.median() - DSL_cost)
# Online_security w/ FO:
FO_Onl_sec = (FO[df.internet_services == 2][df.online_security_enc == 1].monthly_charges.median() - FO_cost)
# online_backup w DSL:
DSL_backup = (DSL[df.internet_services == 2][df.online_backup_enc == 1].monthly_charges.median() - DSL_cost)
# online_backup w Fiber Optic: Need to include phone customers, then subtract the cost of phone
FO_backup = (FO2[df.internet_services == 2][df.online_backup_enc == 1].monthly_charges.median() - FO_cost - phone_svc)
# device_protection w/ DSL:
DSL_dev_prot = (DSL[df.internet_services == 2][df.device_protection_enc == 1].monthly_charges.median() - DSL_cost)
# device_protection w/ Fiber Optic:
FO_dev_prot = (FO[df.internet_services == 2][df.device_protection_enc == 1].monthly_charges.median() - FO_cost)
# tech_support w/ DSL:
DSL_tech = (DSL[df.internet_services == 2][df.tech_support_enc == 1].monthly_charges.median() - DSL_cost)
# tech_support w/ Fiber Optic:
FO_tech = (FO[df.internet_services == 2][df.tech_support_enc == 1].monthly_charges.median() - FO_cost)
# streaming_tv w/ DSL:
DSL_tv = (DSL[df.internet_services == 2][df.streaming_tv_enc == 1].monthly_charges.median() - DSL_cost)
# streaming_tv w/ Fiber Optic:
FO_tv = (FO2[df.internet_services == 2][df.streaming_tv_enc == 1].monthly_charges.median() - FO_cost - phone_svc - phone_extra)
# streaming_movies w/ DSL:
DSL_movies = (DSL[df.internet_services == 2][df.streaming_movies_enc == 1].monthly_charges.median() - DSL_cost)
# streaming_movies w/ Fiber Optic:
FO_movies = (FO2[df.internet_services == 2][df.streaming_movies_enc == 1].monthly_charges.median() - FO_cost - phone_svc)

# %%
Service_costs = pd.DataFrame({
    'Services' : ['phone', 'extra lines', 'DSL', 'Fiber Optic',
                  'DSL Online Security', 'FO Online Security', 
                  'DSL Backup', 'FO Backup', 'DSL Device Prot', 'FO Device Prot', 
                  'DSL Tech Support', 'FO Tech Support', 
                  'DSL TV', 'FO TV', 'DSL Movies', 'FO Movies'],
    'Service Costs' : [phone_svc, phone_extra, DSL_cost, FO_cost, 
                       DSL_Onl_sec, FO_Onl_sec, DSL_backup, FO_backup, 
                       DSL_dev_prot, FO_dev_prot, DSL_tech, FO_tech, 
                       DSL_tv, FO_tv, DSL_movies, FO_movies]
})

Service_costs
# Out:
#                Services  Service Costs
# 0                 phone         19.850
# 1           extra lines          5.200
# 2                   DSL         25.100
# 3           Fiber Optic         24.100
# 4   DSL Online Security          4.500
# 5    FO Online Security          6.350
# 6            DSL Backup          4.750
# 7             FO Backup         31.200
# 8       DSL Device Prot          5.050
# 9        FO Device Prot            nan
# 10     DSL Tech Support          4.450
# 11      FO Tech Support          6.150
# 12               DSL TV          9.600
# 13                FO TV         33.850
# 14           DSL Movies         10.350
# 15            FO Movies         22.350

# %%
# Apparently, Fiber Optic doesn't offer backup, device protection, streaming tv or movies
# lets check that  --> Nope, its wrong. 
# There is only one FO customer with only online backup, and they have a phone contract
# So cost for FO online backup = 75.15 - FO_cost - phone_cost
with pd.option_context('display.max_columns', None):
    display(df[df.contract_type_id == 2][df.internet_services == 2][df.online_backup_enc == 1])
# Out:
#       Unnamed: 0 customer_id churn  churn_enc  tenure  tenure_years  \
# 1138        4728  5176-LDKUH    No          0      48         4.000
#
#       tenure_nml  monthly_charges  monthly_charges_nml  total_charges  \
# 1138       0.431           75.150                0.111       3772.650
#
#       total_charges_nml  senior_citizen  gender_enc  family_support  \
# 1138              0.667               0           0               0
#
#       phone_service_enc  contract_type_id  internet_service_type_id  \
# 1138                  1                 2                         2
#
#       extra_lines  internet_services  has_internet  online_security_enc  \
# 1138            1                  2             1                    0
#
#       online_backup_enc  device_protection_enc  tech_support_enc  \
# 1138                  1                      0                 0
#
#       streaming_tv_enc  streaming_movies_enc  paperless_billing_enc  \
# ...

# %%
# Apparently, Fiber Optic doesn't offer backup, device protection, streaming tv or movies
# lets check that  --> Nope, its wrong. 
# There are no FO customer with only device protection

with pd.option_context('display.max_columns', None):
    display(df[df.contract_type_id == 2][df.internet_services == 2][df.device_protection_enc == 1])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customer_id, churn, churn_enc, tenure, tenure_years, tenure_nml, monthly_charges, monthly_charges_nml, total_charges, total_charges_nml, senior_citizen, gender_enc, family_support, phone_service_enc, contract_type_id, internet_service_type_id, extra_lines, internet_services, has_internet, online_security_enc, online_backup_enc, device_protection_enc, tech_support_enc, streaming_tv_enc, streaming_movies_enc, paperless_billing_enc, pay_elec_check, pay_mail, pay_bank, pay_cc, pay_auto]
# Index: []

# %%
# Apparently, Fiber Optic doesn't offer backup, device protection, streaming tv or movies
# lets check that  --> Nope, its wrong. 
# There are 138 FO customers with device protection, but they have lots of other services...

with pd.option_context('display.max_columns', None):
    display(df[df.contract_type_id == 2][df.device_protection_enc == 1])
# Out:
#       Unnamed: 0 customer_id churn  churn_enc  tenure  tenure_years  \
# 5           4364  8608-OZTLB    No          0      38         3.170
# 17          4894  8268-YDIXR    No          0      56         4.670
# 21          3939  1099-BTKWT    No          0      68         5.670
# 30          4693  4654-DLAMQ    No          0      64         5.330
# 33          4814  6723-WSNTY    No          0      66         5.500
# ...          ...         ...   ...        ...     ...           ...
# 1385        4565  2239-JALAW   Yes          1      58         4.830
# 1390        4485  0727-BMPLR   Yes          1      55         4.580
# 1394        3893  0308-IVGOK    No          0      11         0.920
# 1396        4554  2014-MKGMH    No          0      46         3.830
# 1404        4056  3229-USWAR    No          0      34         2.830
#
#       tenure_nml  monthly_charges  monthly_charges_nml  total_charges  \
# 5          0.191           74.050                0.047       2802.300
# ...

# %%
# Apparently, Fiber Optic doesn't offer backup, device protection, streaming tv or movies
# lets check that  --> Nope, its wrong. 
# There is only one customer with FO service and only streaming tv, and they have a phone with extra lines
# So cost for FO streaming tv = 83 - FO_cost - phone_cost - phone_extra
with pd.option_context('display.max_columns', None):
    display(df[df.contract_type_id == 2][df.internet_services == 2][df.streaming_tv_enc == 1])
# Out:
#      Unnamed: 0 customer_id churn  churn_enc  tenure  tenure_years  \
# 377        4538  1625-JAIIY   Yes          1      68         5.670
#
#      tenure_nml  monthly_charges  monthly_charges_nml  total_charges  \
# 377       1.221           83.000                0.391       5685.800
#
#      total_charges_nml  senior_citizen  gender_enc  family_support  \
# 377              1.155               0           0               2
#
#      phone_service_enc  contract_type_id  internet_service_type_id  \
# 377                  1                 2                         2
#
#      extra_lines  internet_services  has_internet  online_security_enc  \
# 377            2                  2             1                    0
#
#      online_backup_enc  device_protection_enc  tech_support_enc  \
# 377                  0                      0                 0
#
#      streaming_tv_enc  streaming_movies_enc  paperless_billing_enc  \
# ...

# %%
# Apparently, Fiber Optic doesn't offer backup, device protection, streaming tv or movies
# lets check that  --> Nope, its wrong. 
# There are two customers with FO service and only streaming movies, and they have phone service
# So cost for FO streaming tv = their avg - FO_cost - phone_cost
with pd.option_context('display.max_columns', None):
    display(df[df.contract_type_id == 2][df.internet_services == 2][df.streaming_movies_enc == 1])
# Out:
#      Unnamed: 0 customer_id churn  churn_enc  tenure  tenure_years  \
# 455        4089  3863-IUBJR   Yes          1      12         1.000
# 902        4844  7129-AZJDE    No          0      34         2.830
#
#      tenure_nml  monthly_charges  monthly_charges_nml  total_charges  \
# 455      -0.516           53.650               -0.384        696.350
# 902       0.114           78.950                0.215       2647.200
#
#      total_charges_nml  senior_citizen  gender_enc  family_support  \
# 455             -0.418               0           1               2
# 902              0.378               0           1               2
#
#      phone_service_enc  contract_type_id  internet_service_type_id  \
# 455                  1                 2                         1
# 902                  1                 2                         2
#
#      extra_lines  internet_services  has_internet  online_security_enc  \
# ...

# %%
# Also, FO security & tech support are more expensive

# %%
# Compare these averages to the actual monthly charges
df['calc_monthly'] = (np.where(df.extra_lines == 1, phone_svc,
                             np.where(df.extra_lines == 2, (phone_svc + phone_extra), 0)) # phone cost
                      + np.where(df.contract_type_id == 1, DSL_cost,
                               np.where(df.contract_type_id == 2, FO_cost, 0)) # internet cost
                      + np.where((df.contract_type_id == 1) & (df.online_security_enc == 1), DSL_Onl_sec,
                               np.where((df.contract_type_id == 2) & (df.online_security_enc == 1), FO_Onl_sec, 0)) # online security
                      + np.where((df.contract_type_id == 1) & (df.online_backup_enc == 1), DSL_backup,
                                 np.where((df.contract_type_id == 2) & (df.online_backup_enc == 1), FO_backup, 0)) # online backup
                      + np.where((df.contract_type_id == 1) & (df.device_protection_enc == 1), DSL_dev_prot,
                                 np.where((df.contract_type_id == 2) & (df.device_protection_enc == 1),FO_dev_prot, 0)) # Device protection
                      + np.where((df.contract_type_id == 1) & (df.tech_support_enc == 1), DSL_tech,
                               np.where((df.contract_type_id == 2) & (df.tech_support_enc == 1), FO_tech, 0)) # tech support
                      + np.where(df.streaming_tv_enc == 1, DSL_tv, 0) # streaming tv
                      + np.where(df.streaming_movies_enc == 1, DSL_movies, 0) # streaming movies
                     )

df['monthly_diff'] = df.monthly_charges - df.calc_monthly

df.monthly_diff.describe()
# Out:
# count   1271.000
# mean      13.281
# std       24.374
# min      -29.000
# 25%       -0.400
# 50%       23.500
# 75%       25.900
# max       72.350
# Name: monthly_diff, dtype: float64

# %%
# Here i'll turn each of those categories into variables and look at their rate of churn

num_internet_only = df[df.has_internet == 1][df.phone_service_enc == 0][df.internet_services == 1].shape[0]
internet_only_churn = df[df.has_internet == 1][df.phone_service_enc == 0][df.internet_services == 1][df.churn == 'Yes'].shape[0]
internet_rate = (internet_only_churn / num_internet_only)

num_phone_only = df[df.has_internet == 0][df.phone_service_enc == 1].shape[0]
phone_only_churn = df[df.has_internet == 0][df.phone_service_enc == 1][df.churn == 'Yes'].shape[0]
phone_rate = (phone_only_churn / num_phone_only)

num_all = df.shape[0]
num_churn = df[df.churn == 'Yes'].shape[0]
all_rate = (num_churn / num_all)

# customers without phone
num_DSL = DSL.shape[0]
DSL_churn = DSL[df.churn == 'Yes'].shape[0]
DSL_rate = (DSL_churn / num_DSL)

num_FO = FO.shape[0]
FO_churn = FO[df.churn == 'Yes'].shape[0]
FO_rate = (FO_churn / num_FO)

# all DSL customers, even with phone
num_DSL2 = DSL2.shape[0]
DSL2_churn = DSL2[df.churn == 'Yes'].shape[0]
DSL2_rate = (DSL2_churn / num_DSL2)

# all Fiber Optic customers, even with phone
num_FO2 = FO2.shape[0]
FO2_churn = FO2[df.churn == 'Yes'].shape[0]
FO2_rate = (FO2_churn / num_FO2)

print (f'Rate of churn for people who have DSL: {DSL2_rate}')
print (f'Rate of churn for people who have Fiber Optic: {FO2_rate}')
print (f'Rate of churn for people who only have DSL: {DSL_rate}')
print (f'Rate of churn for people who only have Fiber Optic: {FO_rate}')
print (f'Rate of churn for people who only have internet: {internet_rate}')
print (f'Rate of churn for people who only have phone: {phone_rate}')
print (f'Overal rate of churn: {all_rate}')
# Out:
# Rate of churn for people who have DSL: 0.4355263157894737
# Rate of churn for people who have Fiber Optic: 0.15666666666666668
# Rate of churn for people who only have DSL: 0.3620689655172414
# Rate of churn for people who only have Fiber Optic: 0.09090909090909091
# Rate of churn for people who only have internet: 0.45454545454545453
# Rate of churn for people who only have phone: 0.07278481012658228
# Overal rate of churn: 0.2782114975159688

# %%
# Clearly, the DSL service is increasing the rate of churn for our dataset

# %%
num_DSL_online_sec = DSL2[df.online_security_enc == 1].shape[0]
DSL_online_sec_churn = DSL2[df.online_security_enc == 1][df.churn == 'Yes'].shape[0]
DSL_online_sec_rate = (DSL_online_sec_churn / num_DSL_online_sec)

num_FO_online_sec = FO2[df.online_security_enc == 1].shape[0]
FO_online_sec_churn = FO2[df.online_security_enc == 1][df.churn == 'Yes'].shape[0]
FO_online_sec_rate = (FO_online_sec_churn / num_FO_online_sec)

num_DSL_tech = DSL2[df.tech_support_enc == 1].shape[0]
DSL_tech_churn = DSL2[df.tech_support_enc == 1][df.churn == 'Yes'].shape[0]
DSL_tech_rate = (DSL_tech_churn / num_DSL_tech)

num_FO_tech = FO2[df.tech_support_enc == 1].shape[0]
FO_tech_churn = FO2[df.tech_support_enc == 1][df.churn == 'Yes'].shape[0]
FO_tech_rate = (FO_tech_churn / num_FO_tech)

num_DSL_backup = DSL2[df.online_backup_enc == 1].shape[0]
DSL_backup_churn = DSL2[df.online_backup_enc == 1][df.churn == 'Yes'].shape[0]
DSL_backup_rate = (DSL_backup_churn / num_DSL_backup)

num_FO_backup = FO2[df.online_backup_enc == 1].shape[0]
FO_backup_churn = FO2[df.online_backup_enc == 1][df.churn == 'Yes'].shape[0]
FO_backup_rate = (FO_backup_churn / num_FO_backup)

num_DSL_dev_prot = DSL2[df.device_protection_enc == 1].shape[0]
DSL_dev_prot_churn = DSL2[df.device_protection_enc == 1][df.churn == 'Yes'].shape[0]
DSL_dev_prot_rate = (DSL_dev_prot_churn / num_DSL_dev_prot)

num_FO_dev_prot = FO2[df.device_protection_enc == 1].shape[0]
FO_dev_prot_churn = FO2[df.device_protection_enc == 1][df.churn == 'Yes'].shape[0]
FO_dev_prot_rate = (FO_dev_prot_churn / num_FO_dev_prot)

num_DSL_strm_tv = DSL2[df.streaming_tv_enc == 1].shape[0]
strm_DSL_tv_churn = DSL2[df.streaming_tv_enc == 1][df.churn == 'Yes'].shape[0]
strm_DSL_tv_rate = (strm_DSL_tv_churn / num_DSL_strm_tv)

num_FO_strm_tv = FO2[df.streaming_tv_enc == 1].shape[0]
strm_FO_tv_churn = FO2[df.streaming_tv_enc == 1][df.churn == 'Yes'].shape[0]
strm_FO_tv_rate = (strm_FO_tv_churn / num_FO_strm_tv)

num_DSL_strm_mv = DSL2[df.streaming_movies_enc == 1].shape[0]
strm_DSL_mv_churn = DSL2[df.streaming_movies_enc == 1][df.churn == 'Yes'].shape[0]
strm_DSL_mv_rate = (strm_DSL_mv_churn / num_DSL_strm_mv)

num_FO_strm_mv = FO2[df.streaming_movies_enc == 1].shape[0]
strm_FO_mv_churn = FO2[df.streaming_movies_enc == 1][df.churn == 'Yes'].shape[0]
strm_FO_mv_rate = (strm_FO_mv_churn / num_FO_strm_mv)

print ('DSL Churn rates')
print (f'Rate of churn for people who have DSL and online security: {DSL_online_sec_rate}')
print (f'Rate of churn for people who have DSL and tech support: {DSL_tech_rate}')
print (f'Rate of churn for people who have DSL and online backup: {DSL_backup_rate}')
print (f'Rate of churn for people who have DSL and device protection: {DSL_dev_prot_rate}')
print (f'Rate of churn for people who have DSL and streaming tv: {strm_DSL_tv_rate}')
print (f'Rate of churn for people who have DSL and streaming movies: {strm_DSL_mv_rate}')

print ('-----------------------')
print ('Fiber Optic Churn Rates')
print (f'Rate of churn for people who have Fiber Optic and online security: {FO_online_sec_rate}')
print (f'Rate of churn for people who have Fiber Optic and tech support: {FO_tech_rate}')
print (f'Rate of churn for people who have Fiber Optic and online backup: {FO_backup_rate}')
print (f'Rate of churn for people who have Fiber Optic and device protection: {FO_dev_prot_rate}')
print (f'Rate of churn for people who have Fiber Optic and streaming tv: {strm_FO_tv_rate}')
print (f'Rate of churn for people who have Fiber Optic and streaming movies: {strm_FO_mv_rate}')
# Out:
# DSL Churn rates
# Rate of churn for people who have DSL and online security: 0.2876712328767123
# Rate of churn for people who have DSL and tech support: 0.3697478991596639
# Rate of churn for people who have DSL and online backup: 0.36363636363636365
# Rate of churn for people who have DSL and device protection: 0.46706586826347307
# Rate of churn for people who have DSL and streaming tv: 0.5203252032520326
# Rate of churn for people who have DSL and streaming movies: 0.50390625
# -----------------------
# Fiber Optic Churn Rates
# Rate of churn for people who have Fiber Optic and online security: 0.1592920353982301
# Rate of churn for people who have Fiber Optic and tech support: 0.18018018018018017
# Rate of churn for people who have Fiber Optic and online backup: 0.20155038759689922
# Rate of churn for people who have Fiber Optic and device protection: 0.21014492753623187
# Rate of churn for people who have Fiber Optic and streaming tv: 0.2556390977443609
# ...

# %%
# Wow!! There is a clear difference in churn rates between ppl who have DSL and Fiber Optic.
# Ppl with Fiber Optic are less likely to churn
# Also, online security, online backup and tech support seem to reduce churn
# While streaming tv and movies (especially for DSL customers) increase churn

# %%
# How about contract type vs internet services
